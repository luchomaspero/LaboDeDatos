# %%
import numpy as np
import pandas as pd
import seaborn as sns
import seaborn.objects as so
import matplotlib.pyplot as plt
from matplotlib import cm
from formulaic import Formula
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from time import time

# %% [markdown]
# Instalar las siguientes librerias y reiniciar el kernel

# %%
# !pip install tensorflow
# !pip install keras
# !pip install ipympl

# %% [markdown]
# Para Windows (descomentar y ejecutar):

# %%
# %matplotlib notebook
#%matplotlib inline

# %%
# pip install matplotlib --upgrade

# %% [markdown]
# Para Linux (decomentar y ejecutar):

# %%
# %matplotlib widget

# %% [markdown]
# # Descenso Por Gradiente
#
# ### Laboratorio de Datos, IC - FCEN - UBA - 1er. Cuatrimestre 2024
#
# Importamos el Regresor basado en Tensorflow y Keras. Ya viene implementado con Descenso por Gradiente y Descenso por
# Gradiente Estocástico. Sirve para hacer Regresión (Lineal y no Lineal) y para clasificación con Regresión Logística.
#
# También importamos la función ``train_test_split_scale_center`` que separa los datos en entrenamiento y testeo, aplica ``MinMaxScaler`` y, opcionalmente, los
# centra.

# %%
from tf_regressor import Regressor, train_test_split_scale_center

# %% [markdown]
# ### Motivación 1

# %% [markdown]
# Resolver sistemas de ecuaciones *grandes* es computacionalmente costoso. Veamos un ejemplo, con un dataset sintético
# de $11000$ observaciones de $10000$ features cada una (un total de $110$ millones de valores).
#
# Utilizamos el modelo:
# $$Y = \beta_0 + \sum_{i=1}^{10000} \beta_iX_i$$

# %%
# Generamos 11000 muestras aleatorias con 10000 features cada una
np.random.seed(11)
n, m = 11000, 10000
mega_X = np.random.randn(n, m)
simulation_weights = np.random.randint(3, size=mega_X.shape[1])
mega_Y = (mega_X @ simulation_weights + np.random.randn(int(n)) / 10).reshape(-1, 1) # reshape para volverlo una columna

# Normalizamos los datos y los centramos
mega_X_train, mega_X_test, mega_y_train, mega_y_test = train_test_split_scale_center(mega_X, mega_Y,
                                                                                     transform_y=True,
                                                                                     test_size=0.2,
                                                                                     random_state=21)

# %% [markdown]
# <font color='red'>**CUIDADO AL CORRER ESTO, PUEDE EXPLOTAR**<font>

# %%
# # Hacemos regresion lineal con scikit-learn
# model = linear_model.LinearRegression()
# start = time()  # marcamos el tiempo de inicio del entrenamiento
# model.fit(mega_X_train, mega_y_train)
# tiempo_matricial = time() - start   # registramos el tiempo total de entrenamiento
# mse_matricial = mean_squared_error(mega_y_test, model.predict(mega_X_test))
# print('Tiempo total de entrenamiento: ', tiempo_matricial)
# print('MSE en conjunto de testeo: ', mse_matricial)

# %% [markdown]
# ### Motivación 2

# %% [markdown]
# Tenemos un dataset con la evolución de nuevos casos diarios de COVID

# %%
coro = pd.read_csv('../Datos/casos_coronavirus.csv')
coro.reset_index(inplace=True)      # Reseteamos el índice para trabajar con los indices en vez de las fechas
so.Plot(data=coro, x='index', y='confirmados_Nuevos').add(so.Dot())

# %% [markdown]
# ¿Qué tipo de función parece que sigue la evolución de los casos? ¿Podemos plantear un modelo de regresión **lineal**?

# %% [markdown]
# ### 1. Ejemplo: Regresión Lineal con una variable predictora

# %% [markdown]
# Usemos el dataset de ``inmuebles.csv`` para hacer regresión lineal del precio a partir de la superficie del inmueble:
# $$precio = b + w\cdot superficie \qquad (precio \sim superficie) $$

# %%
# Cargamos el dataset
data = pd.read_csv('../Datos/inmuebles.csv')

# Normalizamos los datos
X = data['superficie']
y = data['precio']
X_train, X_test, y_train, y_test = train_test_split_scale_center(X, y, 
                                                                 transform_y=True,  # Normalizamos y también 
                                                                 center=False,      # No centramos los datos
                                                                 test_size=0.2,     # 20% de los datos para testeo
                                                                 random_state=11)   # Semilla para datos de testeo

# %%
# Definimos la funcion del modelo (x, w, b deben respetar ese orden en la declaracion de lambda)
f = lambda x, w, b: b + w*x

# %%
# Inicializamos el modelo (por ahora no tiene nada)
model = Regressor()

# Le agregamos la funcion y especificamos la dimension de w 
model.add_f(f,                  # funcion del modelo 
            dim_w=1,            # dimension de w
            random_state=21,    # semilla para selecciones aleatorias
            opt='gd'            # Especificamos que usamos descenso por gradiente
            )

# Entrenamos el modelo con los conjuntos de entrenamiento
model.fit_(X_train, y_train,        # Conjuntos de entrenamiento 
           epochs=200,              # Cantidad de epocas
           validation_split=0.2,    # 20% de datos para validacion
           learning_rate=0.1)      # Learning rate inicial
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - loss: 0.1794 - val_loss: 0.1038
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.1338 - val_loss: 0.0845
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.1071 - val_loss: 0.0743
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0912 - val_loss: 0.0691
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0816 - val_loss: 0.0664
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0756 - val_loss: 0.0650
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0717 - val_loss: 0.0642
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0689 - val_loss: 0.0637
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0669 - val_loss: 0.0632
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0652 - val_loss: 0.0627
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0638 - val_loss: 0.0621
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0626 - val_loss: 0.0614
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0614 - val_loss: 0.0607
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0603 - val_loss: 0.0600
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0593 - val_loss: 0.0592
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0583 - val_loss: 0.0584
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0573 - val_loss: 0.0575
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0563 - val_loss: 0.0567
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0554 - val_loss: 0.0559
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0545 - val_loss: 0.0550
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0536 - val_loss: 0.0542
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0527 - val_loss: 0.0534
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0518 - val_loss: 0.0526
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0510 - val_loss: 0.0517
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0501 - val_loss: 0.0510
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0493 - val_loss: 0.0502
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0485 - val_loss: 0.0494
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - loss: 0.0477 - val_loss: 0.0486
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0469 - val_loss: 0.0479
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0462 - val_loss: 0.0472
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0454 - val_loss: 0.0465
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0447 - val_loss: 0.0458
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0440 - val_loss: 0.0451
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0433 - val_loss: 0.0444
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0426 - val_loss: 0.0437
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0419 - val_loss: 0.0431
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0413 - val_loss: 0.0424
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.
200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - loss: 0.0100 - val_loss: 0.0115
# Epoch 165/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0100 - val_loss: 0.0114
# Epoch 166/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0099 - val_loss: 0.0114
# Epoch 167/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0099 - val_loss: 0.0113
# Epoch 168/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0098 - val_loss: 0.0112
# Epoch 169/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0098 - val_loss: 0.0112
# Epoch 170/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0097 - val_loss: 0.0111
# Epoch 171/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0097 - val_loss: 0.0111
# Epoch 172/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0096 - val_loss: 0.0110
# Epoch 173/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0096 - val_loss: 0.0110
# Epoch 174/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0095 - val_loss: 0.0109
# Epoch 175/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0095 - val_loss: 0.0109
# Epoch 176/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0094 - val_loss: 0.0108
# Epoch 177/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0094 - val_loss: 0.0108
# Epoch 178/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0093 - val_loss: 0.0107
# Epoch 179/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - loss: 0.0093 - val_loss: 0.0107
# Epoch 180/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0092 - val_loss: 0.0106
# Epoch 181/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0092 - val_loss: 0.0106
# Epoch 182/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0092 - val_loss: 0.0105
# Epoch 183/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0091 - val_loss: 0.0105
# Epoch 184/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0091 - val_loss: 0.0104
# Epoch 185/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0090 - val_loss: 0.0104
# Epoch 186/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0090 - val_loss: 0.0104
# Epoch 187/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0090 - val_loss: 0.0103
# Epoch 188/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0089 - val_loss: 0.0103
# Epoch 189/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0089 - val_loss: 0.0102
# Epoch 190/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0089 - val_loss: 0.0102
# Epoch 191/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0088 - val_loss: 0.0102
# Epoch 192/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0088 - val_loss: 0.0101
# Epoch 193/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step - loss: 0.0088 - val_loss: 0.0101
# Epoch 194/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0087 - val_loss: 0.0100
# Epoch 195/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0087 - val_loss: 0.0100
# Epoch 196/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0087 - val_loss: 0.0100
# Epoch 197/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0086 - val_loss: 0.0099
# Epoch 198/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0086 - val_loss: 0.0099
# Epoch 199/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0086 - val_loss: 0.0099
# Epoch 200/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0085 - val_loss: 0.0098

# %%
# Imprimimos los pesos y el bias resultantes del entrenamiento
print(model.weights_)
print(model.bias_)
# Out:
# [0.7468479]
# 0.02157732

# %%
# Evaluamos el MSE en el conjunto de testeo
model.evaluate(X_test.to_numpy(), y_test.to_numpy(),        # A TensorFlow no le gustan los DataFrame de pandas 
               return_dict=True,                            # Devuelve un diccionario (por si usamos mas de una métrica)
               verbose=0,                                   # No imprima en pantalla el procedimiento de evaluación
               batch_size=len(y_test))
# Out:
# {'loss': 0.010428723879158497}

# %%
# Podemos graficar la evolución de la función de pérdida (MSE)
model.plot_loss()
# Out:
# <div id='0dd7f7e0-33c8-4e21-895c-9c31c03afddc'></div>

# %%
# Podemos graficar como evolucionó el algoritmo a través de las épocas
model.plot_path()
# Out:
# <div id='0847269e-5f1f-45a6-af3d-319b099496b5'></div>

# %%
# Y ver una animación de cómo fue evolucionando la regresión
model.animate_regression(X_train, y_train)
# Out:
# <div id='52b386bd-08c6-4609-b708-88c1ae15b973'></div>

# %% [markdown]
# **Obs:** el desempeño y el resultado del algoritmo dependen de la elección de pesos y bias inciales

# %%
model2 = Regressor()

# Volvamos a entrenar el modelo proporcionándole pesos y bias iniciales
model2.add_f(f,                 # funcion del modelo 
            w0=1,               # peso inicial
            b0=0,               # bias inicial
            opt='gd',            # Especificamos que usamos descenso por gradiente
            random_state=21,    # semilla para selecciones aleatorias
            )

# Entrenamos el modelo con los conjuntos de entrenamiento
model2.fit_(X_train, y_train,        # Conjuntos de entrenamiento 
           epochs=200,              # Cantidad de epocas
           validation_split=0.2,    # 20% de datos para validacion
           learning_rate=0.05)      # Learning rate inicial
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - loss: 0.0166 - val_loss: 0.0191
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0145 - val_loss: 0.0170
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0128 - val_loss: 0.0154
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0116 - val_loss: 0.0141
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 0.0106 - val_loss: 0.0131
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0098 - val_loss: 0.0123
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0092 - val_loss: 0.0116
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0088 - val_loss: 0.0111
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0084 - val_loss: 0.0107
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0081 - val_loss: 0.0104
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0079 - val_loss: 0.0101
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0078 - val_loss: 0.0099
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0076 - val_loss: 0.0097
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0075 - val_loss: 0.0096
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0075 - val_loss: 0.0094
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0074 - val_loss: 0.0093
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0074 - val_loss: 0.0092
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0073 - val_loss: 0.0092
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0073 - val_loss: 0.0091
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0073 - val_loss: 0.0091
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0073 - val_loss: 0.0090
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0072 - val_loss: 0.0090
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0072 - val_loss: 0.0090
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0072 - val_loss: 0.0089
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0072 - val_loss: 0.0089
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0072 - val_loss: 0.0089
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0072 - val_loss: 0.0089
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0072 - val_loss: 0.0089
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0072 - val_loss: 0.0089
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0072 - val_loss: 0.0088
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.0072 - val_loss: 0.0088
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0072 - val_loss: 0.0088
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0072 - val_loss: 0.0088
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0072 - val_loss: 0.0088
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0072 - val_loss: 0.0088
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0072 - val_loss: 0.0088
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0072 - val_loss: 0.0088
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0072 - val_loss: 0.0088
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0072 - val_loss: 0.0088
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0072 - val_loss: 0.0088
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0072 - val_loss: 0.0088
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0072 - val_loss: 0.0088
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.0072 - val_loss: 0.0088
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0072 - val_loss: 0.0088
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0072 - val_loss: 0.0087
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0072 - val_loss: 0.0087
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0072 - val_loss: 0.0087
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0072 - val_loss: 0.0087
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0072 - val_loss: 0.0087
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0072 - val_loss: 0.0087
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0072 - val_loss: 0.0087
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0072 - val_loss: 0.0087
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0072 - val_loss: 0.0087
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0072 - val_loss: 0.0087
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0072 - val_loss: 0.0087
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0072 - val_loss: 0.0087
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step - loss: 0.0072 - val_loss: 0.0087
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0072 - val_loss: 0.0087
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0072 - val_loss: 0.0087
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0072 - val_loss: 0.0087
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0072 - val_loss: 0.0087
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0072 - val_loss: 0.0087
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0072 - val_loss: 0.0087
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0071 - val_loss: 0.0087
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 117/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 118/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 119/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 120/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 121/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 122/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 123/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 124/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 125/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 126/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 127/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 128/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 129/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 130/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 131/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 132/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 133/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 134/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 135/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 136/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 137/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 138/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 139/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 140/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 141/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 142/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 143/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 144/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 145/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 146/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 147/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 148/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 149/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 150/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 151/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 152/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 153/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 154/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 155/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 156/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 157/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 158/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 159/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 160/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 161/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 162/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 163/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 164/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 165/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 166/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 167/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 168/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 169/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0071 - val_loss: 0.0086
# Epoch 170/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 171/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 172/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 173/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 174/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 175/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 176/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 177/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 178/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 179/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 180/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 181/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 182/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 183/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 184/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 185/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 186/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 187/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 188/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 189/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 190/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 191/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 192/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 193/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 194/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 195/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 196/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 197/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 198/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 199/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0071 - val_loss: 0.0085
# Epoch 200/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0071 - val_loss: 0.0085

# %%
# Evaluamos el MSE en el conjunto de testeo
model2.evaluate(X_test.to_numpy(), y_test.to_numpy(),        # A TensorFlow no le gustan los DataFrame de pandas 
               return_dict=True,                            # Devuelve un diccionario (por si usamos mas de una métrica)
               verbose=0,                                   # No imprima en pantalla el procedimiento de evaluación
               batch_size=len(y_test))
# Out:
# {'loss': 0.007164267357438803}

# %%
model2.plot_loss()
# Out:
# <div id='fe39e031-460c-40c9-9e24-6c20a502c433'></div>

# %%
model2.animate_regression(X_train, y_train)
# Out:
# <div id='bf32d2f8-531c-464d-8933-4e83e121b2e4'></div>

# %% [markdown]
# ### 2. Ejemplo: Regresión Lineal con más de una variable predictora

# %% [markdown]
# Vamos a tratar de predecir el peso de los pingüinos según la longitud de su pico y la de su aleta, y su interacción:
# $$body\_mass\_g = b + w_0\cdot bill\_length\_mm + w_1\cdot flipper\_length\_mm +
# w_2\cdot bill\_length\_mm\cdot flipper\_length\_mm$$
# o, escrito con la notación de Wilkinson-Rogers:
# $$body\_mass\_g \sim bill\_length\_mm*flipper\_length\_mm$$

# %%
# Cargamos el dataset
penguins = sns.load_dataset('penguins')
penguins.dropna(inplace=True)

# Elegimos los features, separamos en entrenamiento y testeo y normalizamos
X = penguins[['bill_length_mm', 'flipper_length_mm']]
y = penguins['body_mass_g']
X_train, X_test, y_train, y_test = train_test_split_scale_center(X, y, 
                                                                 transform_y=True,  # Normalizamos y también 
                                                                 center=False,      # No centramos los datos
                                                                 test_size=0.2,     # 20% de los datos para testeo
                                                                 random_state=11)   # Semilla para datos de testeo

# Definimos la funcion del modelo
f = lambda x, w, b: b + w[0]*x[:,0] + w[1]*x[:,1] + w[2]*x[:,0]*x[:,1] 

model3 = Regressor()

# Volvamos a entrenar el modelo con pesos y bias iniciales aleatorios
model3.add_f(f,                 # funcion del modelo
            dim_w= 3,           # dimension de w
            random_state=2077,  # semilla para selecciones aleatorias
            opt='gd'            # Especificamos que usamos descenso por gradiente
            )

# Entrenamos el modelo con los conjuntos de entrenamiento
model3.fit_(X_train, y_train,       # Conjuntos de entrenamiento 
           epochs=200,              # Cantidad de epocas
           validation_split=0.2,    # 20% de datos para validacion
           learning_rate=0.05)      # Learning rate inicial
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 650ms/step - loss: 0.2537 - val_loss: 0.2319
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.2498 - val_loss: 0.2285
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.2460 - val_loss: 0.2252
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.2422 - val_loss: 0.2219
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.2385 - val_loss: 0.2186
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.2349 - val_loss: 0.2154
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.2314 - val_loss: 0.2123
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.2279 - val_loss: 0.2092
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.2244 - val_loss: 0.2061
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - loss: 0.2210 - val_loss: 0.2031
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.2177 - val_loss: 0.2001
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.2144 - val_loss: 0.1972
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.2112 - val_loss: 0.1944
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.2080 - val_loss: 0.1915
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.2049 - val_loss: 0.1887
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.2018 - val_loss: 0.1860
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.1987 - val_loss: 0.1833
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.1958 - val_loss: 0.1806
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.1928 - val_loss: 0.1780
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.1899 - val_loss: 0.1754
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.1871 - val_loss: 0.1729
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.1843 - val_loss: 0.1704
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.1816 - val_loss: 0.1679
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.1789 - val_loss: 0.1655
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0
200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - loss: 0.0727 - val_loss: 0.0695
# Epoch 88/200

# %%
# Imprimimos pesos y bias obtenidos con el entrenamiento
print(model3.weights_)
print(model3.bias_)

# %%
# Calculamos el MSE en el conjunto de testeo
model3.evaluate(X_test.to_numpy(), y_test.to_numpy(),        # A TensorFlow no le gustan los DataFrame de pandas 
               return_dict=True,                            # Devuelve un diccionario (por si usamos mas de una métrica)
               verbose=0,                                   # No imprima en pantalla el procedimiento de evaluación
               batch_size=len(y_test))

# %%
# Graficamos la evolución del MSE
model3.plot_loss()

# %% [markdown]
# ### 3. Ejemplo: Regresión no lineal

# %% [markdown]
# Vamos a realizar Regresión Logística para clasificar pingüinos según su especie (Gentoo o Chinstrap) a partir de su
# peso.

# %%
# Nos quedamos solo con los pingüinos Gentoo o Chinstrap
penguins_clasif = penguins[penguins['species'].isin(['Chinstrap', 'Gentoo'])]

X = penguins_clasif['body_mass_g']
y = penguins_clasif['species']

# Transformamos y a un vector de 1's y 0's:
y = y.apply(lambda t: 1*(t == 'Gentoo'))

# %%
# Graficamos los pesos según la especie
(
    so.Plot()
    .add(so.Dot(), x=X, y=y.iloc[::-1], color=penguins_clasif['species'])
)

# %%
# separamos en entrenamiento y testeo, normalizamos y centramos
X_train, X_test, y_train, y_test = train_test_split_scale_center(X, y, 
                                                                 test_size=0.2,     # 20% de los datos para testeo
                                                                 random_state=10)   # Semilla para datos de testeo

# Definimos la funcion del modelo
f = lambda x, w, b: 1 / (1 + np.e**(-(b + w*x)))

model4 = Regressor()

# Entrenamos el modelo proporcionándole pesos y bias iniciales
model4.add_f(f,                  # funcion del modelo
            w0 = 0,              # peso incial
            b0 = 0,              # bias inicial
            random_state=21,     # semilla para selecciones aleatorias
            opt='gd'             # Especificamos que usamos descenso por gradiente
            )

# Entrenamos el modelo con los conjuntos de entrenamiento
model4.fit_(X_train, y_train,       # Conjuntos de entrenamiento
            classify=True,          # Indicamos que vamos a clasificar
           epochs=50,              # Cantidad de epocas
           validation_split=0.2,    # 20% de datos para validacion
           learning_rate=0.5)       # Learning rate inicial

# %%
# Imprimimos pesos y bias obtenidos con el entrenamiento
print(model4.weights_)
print(model4.bias_)

# %%
# Calculamos el BCE en el conjunto de testeo
model4.evaluate(X_test.to_numpy(), y_test.to_numpy(),       # A TensorFlow no le gustan los DataFrame de pandas 
               return_dict=True,                            # Devuelve un diccionario (por si usamos mas de una métrica)
               verbose=0,                                   # No imprima en pantalla el procedimiento de evaluación
               batch_size=len(y_test))

# %%
# Graficamos la evolución del BCE
model4.plot_loss()

# %%
# Calculamos la prediccion del modelo para X_test
y_pred = (model4.predict(X_test, verbose=0, batch_size=len(y_test)).flatten() > 0.5).astype('int')
y_pred

# %%
# Graficamos la clasificación
(
    so.Plot(x=X_test, y=y_test, color=y_pred)
    .add(so.Dot())
    .label(color='Clasificacion')
    .scale(color={1: 'red', 0:'black'})
)

# %%
# Animamos la regresion resultante en cada época
model4.animate_regression(X_train, y_train)

# %% [markdown]
# ### 4. Ejemplo: Descenso por Gradiente Estocástico

# %% [markdown]
# Rehacemos la clasificación anterior, pero usando SGD

# %%
# Definimos la funcion del modelo
f = lambda x, w, b: 1 / (1 + np.e**(-(b + w*x)))

model5 = Regressor()

# Volvamos a entrenar el modelo, pero con SGD
model5.add_f(f,                  # funcion del modelo
            w0 = 0,              # peso incial
            b0 = 0,              # bias inicial
            random_state=21,     # semilla para selecciones aleatorias
            )

# Entrenamos el modelo con los conjuntos de entrenamiento
model5.fit_(X_train, y_train,       # Conjuntos de entrenamiento
            classify=True,          # Indicamos que vamos a clasificar
            epochs=50,             # Cantidad de epocas
            batch_size=1,           # tamaño del batch
            validation_split=0.2,   # 20% de datos para validacion
            learning_rate=0.5)      # Learning rate inicial

# %%
# Calculamos el BCE en el conjunto de testeo
model5.evaluate(X_test.to_numpy(), y_test.to_numpy(),       # A TensorFlow no le gustan los DataFrame de pandas 
               return_dict=True,                            # Devuelve un diccionario (por si usamos mas de una métrica)
               verbose=0,                                   # No imprima en pantalla el procedimiento de evaluación
               batch_size=len(y_test))

# %%
# Comparado con el modelo de Descenso por Gradiente
model4.evaluate(X_test.to_numpy(), y_test.to_numpy(),       # A TensorFlow no le gustan los DataFrame de pandas 
               return_dict=True,                            # Devuelve un diccionario (por si usamos mas de una métrica)
               verbose=0,                                   # No imprima en pantalla el procedimiento de evaluación
               batch_size=len(y_test))

# %%
# Graficamos la evolución del BCE
model5.plot_loss()

# %%
# Calculamos la prediccion del modelo para X_test y graficamos la clasificacion
y_pred = (model5.predict(X_test, verbose=0, batch_size=len(y_test)).flatten() > 0.5).astype('int')
(
    so.Plot(x=X_test, y=y_test, color=y_pred)
    .add(so.Dot())
    .label(color='Clasificacion')
    .scale(color={1: 'red', 0:'black'})
)

# %%
# Animamos la regresion resultante en cada época
model5.animate_regression(X_train, y_train)

# %% [markdown]
# ### 5. Extras

# %% [markdown]
# #### 5.1 Learning Rate Schedule

# %%
# Volvemos a trabajar con el dataset de pinguinos
penguins = sns.load_dataset('penguins')
penguins.dropna(inplace=True)

# Elegimos los features, separamos en entrenamiento y testeo y normalizamos
X = penguins[['bill_length_mm', 'flipper_length_mm']]
y = penguins['body_mass_g']
X_train, X_test, y_train, y_test = train_test_split_scale_center(X, y, 
                                                                 transform_y=True,  # Normalizamos y también 
                                                                 center=False,      # No centramos los datos
                                                                 test_size=0.2,     # 20% de los datos para testeo
                                                                 random_state=10)   # Semilla para datos de testeo

# Definimos la funcion del modelo
f = lambda x, w, b: b + w[0]*x[:,0] + w[1]*x[:,1] + w[2]*x[:,0]*x[:,1]

# %%
# Consideramos el modelo con learning rate constante 0.05
model_no_schedule = Regressor()

# Inicializamos el modelo con pesos y bias iniciales aleatorios
model_no_schedule.add_f(f,                  # funcion del modelo
            dim_w= 3,           # dimension de w
            random_state=2077,  # semilla para selecciones aleatorias
            )

# Entrenamos el modelo con los conjuntos de entrenamiento
model_no_schedule.fit_(X_train, y_train,        # Conjuntos de entrenamiento 
           epochs=200,              # Cantidad de epocas
           validation_split=0.2,    # 20% de datos para validacion
            batch_size = 6,
            verbose=0
            )

# Calculamos el error en el conjunto de testeo
model_no_schedule.evaluate(X_test.to_numpy(), y_test.to_numpy(),        # A TensorFlow no le gustan los DataFrame de pandas 
               return_dict=True,                            # Devuelve un diccionario (por si usamos mas de una métrica)
               verbose=0,                                   # No imprima en pantalla el procedimiento de evaluación
               batch_size=len(y_test))

# %%
# Lo mismo pero con learning rate variable
model_with_schedule = Regressor()

# Definimos una funcion que disminuya el learning rate a medida que aumentan las epocas
def schedule(epoch, learning_rate):
    if epoch <= 10:
        return learning_rate
    else:
        return learning_rate * (0.95 ** ((epoch + 1) % 10 == 0))
    

# Inicializamos el modelo con pesos y bias iniciales aleatorios
model_with_schedule.add_f(f,      # funcion del modelo
            dim_w= 3,           # dimension de w
            random_state=2077,  # semilla para selecciones aleatorias
            )

# Entrenamos el modelo con los conjuntos de entrenamiento
model_with_schedule.fit_(X_train, y_train,        # Conjuntos de entrenamiento 
           epochs=200,              # Cantidad de epocas
           validation_split=0.2,    # 20% de datos para validacion
           learning_rate=0.1,      # Learning rate inicial
            lr_scheduler=schedule,  # Agregamos la funcion de schedule
            batch_size = 6,
            )

# Calculamos el error en el conjunto de testeo
model_with_schedule.evaluate(X_test.to_numpy(), y_test.to_numpy(),        # A TensorFlow no le gustan los DataFrame de pandas 
               return_dict=True,                            # Devuelve un diccionario (por si usamos mas de una métrica)
               verbose=0,                                   # No imprima en pantalla el procedimiento de evaluación
               batch_size=len(y_test))

# %% [markdown]
# #### 5.2 Early Stopping

# %%
# Agregamos ahora early stopping para que el entrenamiento pare si el MSE no mejora en varias epocas
model_with_schedule_and_es = Regressor()

# Inicializamos el modelo con pesos y bias iniciales aleatorios
model_with_schedule_and_es.add_f(f,      # funcion del modelo
            dim_w= 3,           # dimension de w
            random_state=2077,  # semilla para selecciones aleatorias
            )

# Entrenamos el modelo con los conjuntos de entrenamiento
model_with_schedule_and_es.fit_(X_train, y_train,        # Conjuntos de entrenamiento 
           epochs=200,              # Cantidad de epocas
           validation_split=0.2,    # 20% de datos para validacion
           learning_rate=0.1,      # Learning rate inicial
            lr_scheduler=schedule,  # Agregamos la funcion de schedule
            batch_size = 6,
            early_stopping=True,     # Activamos el early stopping
            start_from_epoch=50,    # Entra en funcionamiento a partir de la epoca 50
            patience=30,            # Si en 30 epocas el MSE no mejora, para
            )

# Calculamos el error en el conjunto de testeo
model_with_schedule_and_es.evaluate(X_test.to_numpy(), y_test.to_numpy(),        # A TensorFlow no le gustan los DataFrame de pandas 
               return_dict=True,                            # Devuelve un diccionario (por si usamos mas de una métrica)
               verbose=0,                                   # No imprima en pantalla el procedimiento de evaluación
               batch_size=len(y_test))

# %% [markdown]
# ### 6. Comparación con resolución matricial

# %%
import tensorflow as tf

# Ahora con SGD
model = Regressor()
# f = lambda x, w, b: b + sum(w[i] * x[:, i] for i in range(len(w)))
f = lambda x, w, b: b + tf.linalg.matvec(x,w)
model.add_f(f, 
           w0=np.zeros(mega_X_train.shape[1]),
           b0=0,
           random_state=21
)

start = time()
model.fit_(mega_X_train, mega_y_train,
           batch_size=100,
           epochs=200,             # Cantidad de epocas
           verbose=0,              # No imprime progreso
           clipnorm=2,             # Normaliza el gradiente
           validation_split=0.2)   # 20% de datos para validacion)

tiempo_SGD = time() - start
print('Tiempo total de entrenamiento: ', tiempo_SGD)

loss_dict = model.evaluate(mega_X_test.to_numpy(), mega_y_test.to_numpy(),   # A TensorFlow no le gustan los 
                           # DataFrame de 
                           # pandas 
               return_dict=True,                            # Devuelve un diccionario (por si usamos mas de una métrica)
               verbose=0,                                   # No imprima en pantalla el procedimiento de evaluación
               batch_size=len(mega_y_test))
mse_SGD = loss_dict['loss']
print('MSE en conjunto de testeo: ', mse_SGD)

# %%
print('Tiempo total de entrenamiento: ', tiempo_matricial)
print('MSE en conjunto de testeo: ', mse_matricial)

# %%
print(f'En {100*(tiempo_SGD / tiempo_matricial):.2f}% de tiempo, SGD obtuvo una solucion con {100*(mse_SGD / mse_matricial-1):.2f}% mas error cuadratico medio')

# %% [markdown]
# ### 7. Incluyendo `formulaic`

# %% [markdown]
# A veces podríamos querer usar `formulaic` para modelos **lineales** más complejos. Como ejemplo, supongamos que queremos aproximar el precio de un inmueble con un modelo de la forma:
# $$precio = b + w_1e^{superficie} + w_2\,zona$$
#
# Para esto nos vendría bien usar `formulaic`

# %%
# Cargamos el dataset
data = pd.read_csv('../Datos/inmuebles.csv')

# Transformamos los datos segun la formula (le dejamos el intercept a LinearRegression o a Regressor)
y, X = Formula('precio~np.exp(superficie)+zona-1').get_model_matrix(data)

# Normalizamos los datos (no los centramos para no alterar las variables dummy) y dividimos en entrenamiento y testeo
X_train, X_test, y_train, y_test = train_test_split_scale_center(X, y, 
                                                                 transform_y=True,  # Normalizamos y también 
                                                                 center=False,      # No centramos los datos
                                                                 test_size=0.2,     # 20% de los datos para testeo
                                                                 random_state=11)   # Semilla para datos de testeo

# %% [markdown]
# #### 7.1 Con `LinearRegression` de `scikit-learn`

# %%
# Hacemos la regresion con los datos transformados
model = linear_model.LinearRegression()
model.fit(X_train, y_train)

# Calculamos el error cuadratico medio
mean_squared_error(y_test, model.predict(X_test))

# %% [markdown]
# #### 7.2 Con `Regressor` de `tf_regressor`

# %%
# Escribimos la funcion del modelo, teniendo en cuenta a que corresponde cada columna de X_train:
# Columna 0: e^superficie
# Columnas 1 a 3: variables dummy para 'zona'
f = lambda x, w, b: b + w[0]*x[:,0] + w[1]*x[:,1] + w[2]*x[:,2] + w[3]*x[:,3]

model = Regressor()

model.add_f(f,                  # funcion del modelo
            w0=np.zeros(4),     # Vector inicial de 0's de longitud 4
            b0=0,
            random_state=21,
            )

# Entrenamos el modelo con los conjuntos de entrenamiento
model.fit_(X_train, y_train,
           epochs=200,              
           validation_split=0.2,      
           learning_rate=0.05,
           batch_size=5,
           verbose=0)

model.evaluate(X_test.to_numpy(), y_test.to_numpy(),
               return_dict=True,                            
               verbose=0,                                   
               batch_size=len(y_test))
